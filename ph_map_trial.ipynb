# %%
# !pip3 install contextily

# %%
import contextily as cx
import matplotlib.pyplot as plt

# %%
west, south, east, north = (117, 5.5, 127.537423944, 19.5)

# %%
ghent_img, ghent_ext = cx.bounds2img(west,south,east,north,ll=True,source=cx.providers.Stamen.Toner)

# %%
ghent_img.shape
# Out:
# (1792, 1280, 4)

# %%
ghent_ext
# Out:
# (12836528.782099357,
#  14401959.121379767,
#  313086.06785608083,
#  2504688.5428486555)

# %%
f, ax = plt.subplots(1, figsize=(9, 9))
ax.imshow(ghent_img, extent=ghent_ext)
